# %% [markdown]
# # Variable
#
# ## Assignment
# Assignment is a way to generate a variable:
#
# `a = 3`
# - On right side: **value**
# - On left side: **variable**
#
# "a **value** `3` is assigned to the **variable** `a`"

# %%
a = 3

# %% [markdown]
# ### Once you generated a variable (`a`), you can use it instead of its value (`3`)

# %%
a
# Out:
# 3

# %%
a + 3
# Out:
# 6

# %% [markdown]
# ### Python always evaluate the right side first and assign it into the variable on the left side later

# %% [markdown]
# "the right side, `a + 3` is evaluated first" $\rightarrow$ `6`
#
# "the evaluated **value**, `6` is assigned to the new **variable** `b` on the left side"

# %%
b = a + 3

# %%
b
# Out:
# 6

# %% [markdown]
# # Some Data Types

# %% [markdown]
# ## `Number`

# %% [markdown]
# #### integer `int`

# %%
3
# Out:
# 3

# %%
-1
# Out:
# -1

# %%
int(3.9)
# Out:
# 3

# %% [markdown]
# #### boolean: True / False `bool`

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
1 == 2
# Out:
# False

# %% [markdown]
# #### floating point `float`

# %%
2.3
# Out:
# 2.3

# %%
2.0e3
# Out:
# 2000.0

# %% [markdown]
# #### complex `complex`

# %%
1j
# Out:
# 1j

# %%
1.2 + 0.3j
# Out:
# (1.2+0.3j)

# %% [markdown]
# ## String

# %%
'Ich bin AB'
# Out:
# 'Ich bin AB'

# %% [markdown]
# ## List

# %% [markdown]
# #### Single object (number)

# %%
3
# Out:
# 3

# %% [markdown]
# #### Single object (string)

# %%
'LMU'
# Out:
# 'LMU'

# %% [markdown]
# #### 'list' of multiple objects (of same type)

# %%
[3,4]
# Out:
# [3, 4]

# %% [markdown]
# #### 'list' of multiple objects (of different types)

# %%
[3,'LMU']  # 'integer' and 'string' type objects are in a same 'list'-type object
# Out:
# [3, 'LMU']

# %% [markdown]
# #### Since 'list' is also an object, it can also be assigned into a variable

# %%
l = [3,4,5]

# %%
l
# Out:
# [3, 4, 5]

# %% [markdown]
# ## An element of list can be accessed by 'indexing'

# %% [markdown]
# ### Index starts from `0` (zero)

# %%
l[0]
# Out:
# 3

# %%
l[1]
# Out:
# 4

# %%
l[2]  # last index
# Out:
# 5

# %% [markdown]
# ### length of a list = number of elements

# %%
len(l)
# Out:
# 3

# %%
# l[3]  # it would raises error: out-of-range-index

# %% [markdown]
# ### negative index counts from the end

# %%
l[2]  # last index of the list (positive index)
# Out:
# 5

# %%
l[-1]  # last index of the list (negative index)
# Out:
# 5

# %% [markdown]
# ## Unpacking the list

# %%
l = [3,4,5]

# %%
a, b, c = l

# %%
a
# Out:
# 3

# %%
b
# Out:
# 4

# %%
c
# Out:
# 5

# %% [markdown]
# ## Slicing

# %%
li = [3,5,7,9]

# %%
li
# Out:
# [3, 5, 7, 9]

# %% [markdown]
# ### Using `i:j` expression

# %%
li[0:2]
# Out:
# [3, 5]

# %%
li[1:3]
# Out:
# [5, 7]

# %% [markdown]
# ### Sliced squence is also a sequence

# %%
sliced_list = li[2:4]

# %%
sliced_list
# Out:
# [7, 9]

# %%
sliced_list[0]
# Out:
# 7

# %% [markdown]
# ## Tuple

# %% [markdown]
# ### How to make `tuple`

# %%
tup = (3,4,5)

# %% [markdown]
# ### Indexing `tuple`

# %%
tup[0]
# Out:
# 3

# %%
tup[2]
# Out:
# 5

# %% [markdown]
# ### Comparing `tuple` with `list` : 'mutability' (changablity)
# You can change element of `list` after it is created, but not for `tuple`

# %%
li = [2,'py',4.5]
tu = (2,'py',4.5)

# %% [markdown]
# #### Before changing

# %%
li
# Out:
# [2, 'py', 4.5]

# %%
tu
# Out:
# (2, 'py', 4.5)

# %% [markdown]
# #### Trying to change an element of list and tuple respectively

# %%
li[0] = 'changed'  # list's element can be changed

# %%
# tu[0] = 'changed'  # this would raise an error. Uncomment to run it.

# %% [markdown]
# # Arithmetic : $+\times-\div\cdots$

# %% [markdown]
# ## Between numerics

# %% [markdown]
# #### Addition : `+`

# %%
3 + 4.3
# Out:
# 7.3

# %% [markdown]
# #### Multiplication : `*`

# %%
2 * 3
# Out:
# 6

# %% [markdown]
# #### Substraction : `-`

# %%
10 - 3
# Out:
# 7

# %% [markdown]
# #### Division : `/`

# %%
10 / 3
# Out:
# 3.3333333333333335

# %% [markdown]
# #### $a^n$ = `a**n`

# %%
3 ** 2
# Out:
# 9

# %%
4 ** 0.5
# Out:
# 2.0

# %% [markdown]
# #### quotient `//` and remainder `%`

# %%
10 // 3  # quotient
# Out:
# 3

# %%
10 % 3  # remainder
# Out:
# 1

# %% [markdown]
# ## Between strings

# %%
'hallo' + 'oooo'
# Out:
# 'hallooooo'

# %% [markdown]
# #### Not all object support all operators

# %%
# 'hdd' - 'dfj'  # this would raise an error. Uncomment to run it.

# %% [markdown]
# ## Between different types of objects

# %% [markdown]
# ##### string and integer

# %%
'hi' * 3  # it duplicates a given string
# Out:
# 'hihihi'

# %%
3 * 'hi'  # they commute
# Out:
# 'hihihi'

# %% [markdown]
# # `for` statement

# %%
l = [3,4,5]

# %%
print(l[0])
print(l[1])
print(l[2])
# Out:
# 3
# 4
# 5

# %% [markdown]
# ### Using `range()` function

# %%
for index in range(3):
    print(l[index])
# Out:
# 3
# 4
# 5

# %%
for element in l:
    print(element)
# Out:
# 3
# 4
# 5

# %% [markdown]
# ### Indentation is important

# %%
# for element in l:
# print(element)

# %% [markdown]
# # `if` statement

# %% [markdown]
# ### Conditional Statement : True / False

# %%
1 == 2
# Out:
# False

# %%
l[2] == l[-1]
# Out:
# True

# %%
same = (l[2] == l[-1])

# %%
same
# Out:
# True

# %%
type(same)
# Out:
# bool

# %% [markdown]
# ### if statement

# %%
if same:
    print('they are same')
# Out:
# they are same

# %% [markdown]
# ### Indentation is important

# %%
# if same:
# print('they are same')

# %%
if same:
    print('they are same')
else:
    print('they are not same')
# Out:
# they are same

# %% [markdown]
# ---

# %% [markdown]
# # Function
#
# ### take [input] return [output]

# %% [markdown]
# ## 1-in / 1-out

# %%
def square(x):
    x_square = x ** 2
    return x_square

# %%
square(3)
# Out:
# 9

# %% [markdown]
# ## 2-in / 1-out

# %%
def make_complex(real, imag):
    complex_number = real + imag * 1j
    return complex_number

# %%
make_complex(-0.2, 0.1)
# Out:
# (-0.2+0.1j)

# %% [markdown]
# #### There is a built-in function of same functionality

# %%
complex(-0.2, 0.1)
# Out:
# (-0.2+0.1j)

# %% [markdown]
# ## 1-in / 2-out

# %%
def split_complex(complex_number):
    real = complex_number.real
    imag = complex_number.imag
    return real, imag  # multiple output is listed in comma-separated form
    # return (real, imag)  # same expression as above

# %%
results = split_complex(c)

# %%
results
# Out:
# (5, 0)

# %%
type(results)
# Out:
# tuple

# %%
result1, result2 = results

# %%
result1
# Out:
# 5

# %%
result2
# Out:
# 0

# %% [markdown]
# #### or

# %%
result1, result2 = split_complex(c)

# %%
def split_complex(complex_number):
    real = complex_number.real
    imag = complex_number.imag
    return real, imag  # multiple output is listed in comma-separated form

# %% [markdown]
# ### Multiple outputs

# %% [markdown]
# # Using Module

# %% [markdown]
# ### `import` _module_

# %%
import math

# %%
math.sqrt(4)
# Out:
# 2.0

# %% [markdown]
# ### `import` _module_ `as` _nickname_

# %%
import math as m

# %%
m.sqrt(4)
# Out:
# 2.0

# %% [markdown]
# ### `from` _module_ `import` _object_

# %%
from math import sqrt

# %%
sqrt(4)
# Out:
# 2.0

# %% [markdown]
# # {method, attribute} $\in$ Object

# %% [markdown]
# ### Almost everything is `object`

# %%
c = 1.2 - 0.1j  # a complex number

# %%
c
# Out:
# (1.2-0.1j)

# %% [markdown]
# ### Every object can have its own _attribute_

# %%
c.real
# Out:
# 1.2

# %%
c.imag
# Out:
# -0.1

# %% [markdown]
# ### Every object can have its own _method_
# #### [NOTE] a `method` of an object can be thought as a `function` which belongs to that object

# %%
c
# Out:
# (1.2-0.1j)

# %%
c.conjugate()
# Out:
# (1.2+0.1j)

# %% [markdown]
# ### `Tab` after `.` to see possible methods

# %%
c.real
# Out:
# 1.2
